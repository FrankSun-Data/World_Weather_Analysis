# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lats, lngs)
lat_lng

# %%
from citipy import citipy
coordinates = list(lat_lng)
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
        citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# w
# tuatapere nz
# attawapiskat ca
# victoria sc
# kuntaur gm
# rikitea pf
# norman wells ca
# albany au
# lasa cn
# east london za
# saint-philippe re
# busselton au
# thompson ca
# sao filipe cv
# airai pw
# ushuaia ar
# odienne ci
# arraial do cabo br
# atuona pf
# mahebourg mu
# naze jp
# arauca co
# busselton au
# severo-kurilsk ru
# tuktoyaktuk ca
# busselton au
# khatanga ru
# wilmington us
# barrow us
# albany au
# hobart au
# yamada jp
# ballina ie
# wanderlandia br
# qaanaaq gl
# nishihara jp
# quartucciu it
# marzuq ly
# vao nc
# mar del plata ar
# leningradskiy ru
# rikitea pf
# mataura pf
# newport us
# kruisfontein za
# puerto ayora ec
# san roque ph
# mocambique mz
# bethel us
# barrow us
# cabo san lucas mx
# kavieng pg
# yellowknife ca
# thompson ca
# korla cn
# attawapiskat ca
# sabang id
# ushuaia ar
# khatra in
# inuvik ca
# wahran dz
# taoudenni ml
# platanos gr
# souillac mu
# margate za
# busselton au
# bambous virieux mu
# mataura pf
# rosarito mx
# rikitea pf
# zhangye cn
# ushuaia ar
# cape town za
# victoria sc
# henties bay na
# mount pleasant us
# okhotsk ru
# san cristobal ec
# chuy uy
# kavieng pg
# punta arenas cl
# kodiak us
# muncar id
# vaini to
# atar mr
# cape town za
# hilo us
# mar del plata ar
# jamestown sh
# khonuu ru
# chokurdakh ru
# bredasdorp za
# beni cd
# aykino ru
# busselton au
# clyde river ca
# mount isa au
# mana gf
# chokurdakh ru
# ushuaia ar
# santiago ph
# tuktoyaktuk ca
# shache cn
# upernavik gl
# mahebourg mu
# bocana de paiwas ni
# barentsburg sj
# altay cn
# mikhaylovka kz
# albany au
# longyearbyen sj
# severo-kurilsk ru
# kapaa us
# ribeira grande pt
# mykhaylivka ua
# alofi nu
# avera pf
# punta arenas cl
# alakurtti ru
# klaksvik fo
# torbay ca
# rio brilhante br
# bredasdorp za
# vaini to
# praya id
# lusambo cd
# laguna br
# thinadhoo mv
# jamestown sh
# bluff nz
# bull savanna jm
# bathsheba bb
# georgetown sh
# port alfred za
# albany au
# portlethen gb
# huangnihe cn
# longjiang cn
# bilibino ru
# lakatoro vu
# carnarvon au
# berlevag no
# severo-kurilsk ru
# busselton au
# kamenka ru
# qaanaaq gl
# kapaa us
# fortuna us
# ahipara nz
# hilo us
# uslar de
# souillac mu
# rikitea pf
# trelew ar
# nikolskoye ru
# wanning cn
# rikitea pf
# hermanus za
# taoudenni ml
# sabang id
# castro cl
# hithadhoo mv
# new norfolk au
# hobart au
# mamit in
# saint-philippe re
# yuli tw
# albany au
# sangar ru
# egvekinot ru
# guerrero negro mx
# thanh hoa vn
# isangel vu
# alofi nu
# thompson ca
# luderitz na
# cherskiy ru
# zabinka by
# luanda ao
# lufilufi ws
# doctor pedro p. pena py
# upernavik gl
# murfreesboro us
# vila franca do campo pt
# hirara jp
# riyadh sa
# taolanaro mg
# saint george bm
# bone id
# vaini to
# tasiilaq gl
# castro cl
# ilulissat gl
# abancay pe
# okakarara na
# lagoa pt
# gornyak ua
# carnarvon au
# new norfolk au
# east london za
# cherskiy ru
# busselton au
# cape town za
# xining cn
# georgetown sh
# port lincoln au
# petropavlovsk-kamchatskiy ru
# upington za
# east london za
# bluff nz
# mar del plata ar
# bluff nz
# port alfred za
# cherskiy ru
# hami cn
# kodiak us
# fortuna us
# ushuaia ar
# carnarvon au
# ketchikan us
# hobart au
# kapuskasing ca
# castro cl
# kortkeros ru
# buala sb
# rikitea pf
# tarakan id
# iqaluit ca
# rio grande br
# ponferrada es
# sentyabrskiy ru
# kapaa us
# cape town za
# ilulissat gl
# hunza pk
# bluff nz
# new norfolk au
# new norfolk au
# miracema do tocantins br
# vidim ru
# jamestown sh
# guaraniacu br
# albany au
# mataura pf
# lebu cl
# hermanus za
# rikitea pf
# upernavik gl
# port alfred za
# tual id
# mataura pf
# pathein mm
# roald no
# sainte-martine ca
# puerto ayora ec
# arraial do cabo br
# tuktoyaktuk ca
# port lincoln au
# hithadhoo mv
# polovinnoye ru
# inta ru
# kattivakkam in
# butaritari ki
# rikitea pf
# cabo san lucas mx
# nevers fr
# ushuaia ar
# kirakira sb
# vanimo pg
# morro bay us
# hobart au
# kortkeros ru
# necochea ar
# saint-paul re
# salekhard ru
# albany au
# rikitea pf
# bluff nz
# punta arenas cl
# temaraia ki
# vila vu
# vila franca do campo pt
# port lincoln au
# souillac mu
# tuatapere nz
# russell nz
# hermanus za
# hermanus za
# thompson ca
# avera pf
# dwarka in
# eyl so
# khatanga ru
# qaanaaq gl
# dong hoi vn
# meulaboh id
# kaitangata nz
# bredasdorp za
# busselton au
# boca do acre br
# hilo us
# rikitea pf
# ushuaia ar
# vaitupu wf
# berdyuzhye ru
# lockhart us
# torbay ca
# rikitea pf
# roald no
# saskylakh ru
# thompson ca
# vila franca do campo pt
# ushuaia ar
# east london za
# mount isa au
# ust-kuyga ru
# vaitupu wf
# coquimbo cl
# busselton au
# porto novo cv
# manggar id
# punta arenas cl
# albany au
# at-bashi kg
# umm lajj sa
# ushuaia ar
# kalmunai lk
# half moon bay us
# bredasdorp za
# opobo ng
# kamenka ru
# tiksi ru
# nikolskoye ru
# punta arenas cl
# ushuaia ar
# ushuaia ar
# ushuaia ar
# westport nz
# hilo us
# airai pw
# hobart au
# ushuaia ar
# hithadhoo mv
# east london za
# tecoanapa mx
# puerto ayora ec
# upernavik gl
# hervey bay au
# jamestown sh
# karaul ru
# cape town za
# burnie au
# wynyard ca
# whitefish us
# albany au
# umm kaddadah sd
# barbar sd
# mahebourg mu
# ushuaia ar
# rikitea pf
# vaini to
# tuktoyaktuk ca
# port alfred za
# saskylakh ru
# saint george bm
# ayan ru
# khatanga ru
# ushuaia ar
# lichinga mz
# norman wells ca
# pevek ru
# tiko cm
# mataura pf
# yar-sale ru
# lieksa fi
# jamestown sh
# avarua ck
# port alfred za
# tibacuy co
# bolondron cu
# albany au
# scarborough tt
# nikolskoye ru
# hermanus za
# fort pierce us
# shangrao cn
# rikitea pf
# san borja bo
# busselton au
# upernavik gl
# hauknes no
# waipawa nz
# ushuaia ar
# vaini to
# punta arenas cl
# alice springs au
# kapaa us
# tingi tz
# bengkulu id
# pokrovsk-uralskiy ru
# kapaa us
# mys shmidta ru
# bogorodskoye ru
# barrow us
# margate za
# sinnamary gf
# albany au
# esperance au
# bredasdorp za
# vaini to
# mys shmidta ru
# rikitea pf
# aranda de duero es
# hilo us
# ushuaia ar
# saint-philippe re
# rikitea pf
# rikitea pf
# husavik is
# verkhoyansk ru
# avera pf
# makarov ru
# port alfred za
# mataura pf
# mount darwin zw
# vytegra ru
# huarmey pe
# samusu ws
# kruisfontein za
# yellowknife ca
# qostanay kz
# mar del plata ar
# ponta do sol cv
# hilo us
# kaitangata nz
# punta arenas cl
# rosetta eg
# jamestown sh
# khatanga ru
# rikitea pf
# cururupu br
# caborca mx
# hinton ca
# vao nc
# mahebourg mu
# ushuaia ar
# lorengau pg
# atuona pf
# deputatskiy ru
# glendive us
# busselton au
# tuktoyaktuk ca
# barrow us
# bambous virieux mu
# puerto ayora ec
# mataura pf
# barrow us
# salalah om
# albany au
# baykit ru
# sentyabrskiy ru
# sao felix do xingu br
# taburi ph
# sorong id
# kapaa us
# albany au
# nanortalik gl
# sola vu
# lavrentiya ru
# vaini to
# jamestown sh
# butaritari ki
# banjar id
# ilebo cd
# pevek ru
# howard springs au
# jaguey grande cu
# barrow us
# bethel us
# asayita et
# dikson ru
# airai pw
# port alfred za
# kapaa us
# albany au
# shimanovsk ru
# jamestown sh
# sena madureira br
# mollendo pe
# mataura pf
# rawson ar
# east london za
# manokwari id
# mataura pf
# mataura pf
# chaa-khol ru
# havoysund no
# port keats au
# kedougou sn
# cape town za
# illoqqortoormiut gl
# vila franca do campo pt
# qaanaaq gl
# dauriya ru
# duz tn
# kapaa us
# port alfred za
# ondorhaan mn
# mataura pf
# atuona pf
# kavieng pg
# nanortalik gl
# kaitangata nz
# mezen ru
# urumqi cn
# ushuaia ar
# castro cl
# new norfolk au
# albany au
# castro cl
# naze jp
# hami cn
# eston ca
# bethel us
# bredasdorp za
# barrow us
# cabo san lucas mx
# port alfred za
# kodiak us
# mataura pf
# grand river south east mu
# ayios kirikos gr
# avarua ck
# vaini to
# ushuaia ar
# mataura pf
# bambous virieux mu
# shatrovo ru
# hithadhoo mv
# fort smith us
# tecoanapa mx
# rikitea pf
# severo-kurilsk ru
# castro cl
# moelv no
# krasnokamensk ru
# vao nc
# nador ma
# mujiayingzi cn
# sitka us
# cape town za
# saint andrews ca
# illoqqortoormiut gl
# gigmoto ph
# east london za
# cape town za
# nsanje mw
# saleaula ws
# taolanaro mg
# saint-philippe re
# atuona pf
# vao nc
# isiro cd
# belushya guba ru
# ushuaia ar
# tondon gn
# mahebourg mu
# inverell au
# pitimbu br
# guerrero negro mx
# georgetown sh
# kapaa us
# ayorou ne
# castro cl
# kaitangata nz
# keita ne
# busselton au
# hobart au
# upernavik gl
# cabo san lucas mx
# ushuaia ar
# provideniya ru
# new norfolk au
# mataura pf
# hermanus za
# upernavik gl
# coulihaut dm
# cape town za
# grand river south east mu
# ahipara nz
# ukiah us
# port alfred za
# taolanaro mg
# georgetown sh
# wloszczowa pl
# mochudi bw
# panjab af
# amot no
# merauke id
# graham us
# aguimes es
# jamestown sh
# hobart au
# attawapiskat ca
# mar del plata ar
# souillac mu
# bonnyville ca
# mogadishu so
# busselton au
# opunake nz
# georgetown sh
# port alfred za
# tiksi ru
# sao filipe cv
# labuhan id
# ejido ve
# kismayo so

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    #print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather["weather"][0]["description"])
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})
        
        print(f"Processed Record {record_count} of Set {set_count} | {city}")

    # If an error is experienced, skip the city.
    except:
        #print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# d Record 20 of Set 8 | lockhart
# overcast clouds
# Processed Record 21 of Set 8 | saskylakh
# clear sky
# Processed Record 22 of Set 8 | ust-kuyga
# broken clouds
# Processed Record 23 of Set 8 | porto novo
# overcast clouds
# Processed Record 24 of Set 8 | manggar
# overcast clouds
# Processed Record 25 of Set 8 | at-bashi
# clear sky
# Processed Record 26 of Set 8 | umm lajj
# overcast clouds
# Processed Record 27 of Set 8 | kalmunai
# haze
# Processed Record 28 of Set 8 | half moon bay
# clear sky
# Processed Record 30 of Set 8 | westport
# overcast clouds
# Processed Record 31 of Set 8 | tecoanapa
# clear sky
# Processed Record 32 of Set 8 | hervey bay
# overcast clouds
# Processed Record 34 of Set 8 | burnie
# overcast clouds
# Processed Record 35 of Set 8 | wynyard
# broken clouds
# Processed Record 36 of Set 8 | whitefish
# few clouds
# Processed Record 37 of Set 8 | umm kaddadah
# overcast clouds
# Processed Record 39 of Set 8 | ayan
# few clouds
# Processed Record 40 of Set 8 | lichinga
# overcast clouds
# Processed Record 41 of Set 8 | tiko
# scattered clouds
# Processed Record 42 of Set 8 | lieksa
# overcast clouds
# Processed Record 43 of Set 8 | tibacuy
# overcast clouds
# Processed Record 44 of Set 8 | bolondron
# broken clouds
# Processed Record 45 of Set 8 | scarborough
# broken clouds
# Processed Record 46 of Set 8 | fort pierce
# few clouds
# Processed Record 47 of Set 8 | shangrao
# broken clouds
# Processed Record 48 of Set 8 | san borja
# broken clouds
# Processed Record 49 of Set 8 | hauknes
# light rain
# Processed Record 50 of Set 8 | waipawa
# clear sky
# Processed Record 1 of Set 9 | alice springs
# light rain
# Processed Record 2 of Set 9 | tilichiki
# broken clouds
# Processed Record 5 of Set 9 | ginir
# light rain
# Processed Record 7 of Set 9 | bonthe
# broken clouds
# Processed Record 8 of Set 9 | luan
# light rain
# Processed Record 9 of Set 9 | whitehorse
# overcast clouds
# Processed Record 10 of Set 9 | lorengau
# broken clouds
# Processed Record 11 of Set 9 | bambari
# broken clouds
# Processed Record 12 of Set 9 | cabinda
# broken clouds
# Processed Record 13 of Set 9 | siderno
# clear sky
# Processed Record 14 of Set 9 | jidong
# overcast clouds
# Processed Record 15 of Set 9 | maniitsoq
# overcast clouds
# Processed Record 16 of Set 9 | pochutla
# few clouds
# Processed Record 17 of Set 9 | batagay
# broken clouds
# Processed Record 18 of Set 9 | koslan
# clear sky
# Processed Record 19 of Set 9 | port elizabeth
# broken clouds
# Processed Record 20 of Set 9 | kamloops
# few clouds
# Processed Record 21 of Set 9 | nanakuli
# light rain
# Processed Record 22 of Set 9 | ucluelet
# few clouds
# Processed Record 23 of Set 9 | vila velha
# broken clouds
# Processed Record 24 of Set 9 | chernyshevskiy
# light rain
# Processed Record 25 of Set 9 | dingle
# clear sky
# Processed Record 26 of Set 9 | port macquarie
# overcast clouds
# Processed Record 27 of Set 9 | lagunas
# overcast clouds
# Processed Record 28 of Set 9 | przasnysz
# light rain
# Processed Record 29 of Set 9 | whitianga
# overcast clouds
# Processed Record 30 of Set 9 | sakata
# clear sky
# Processed Record 31 of Set 9 | abha
# broken clouds
# Processed Record 33 of Set 9 | chaoyang
# clear sky
# Processed Record 34 of Set 9 | rocha
# scattered clouds
# Processed Record 35 of Set 9 | labuhan
# light rain
# Processed Record 36 of Set 9 | saint-joseph
# overcast clouds
# Processed Record 37 of Set 9 | dom pedrito
# clear sky
# Processed Record 38 of Set 9 | romitan
# overcast clouds
# Processed Record 39 of Set 9 | mednogorsk
# scattered clouds
# Processed Record 40 of Set 9 | aquiraz
# scattered clouds
# Processed Record 41 of Set 9 | sand springs
# scattered clouds
# Processed Record 42 of Set 9 | mollendo
# overcast clouds
# Processed Record 43 of Set 9 | zavet
# overcast clouds
# Processed Record 44 of Set 9 | ust-barguzin
# clear sky
# Processed Record 45 of Set 9 | faanui
# clear sky
# Processed Record 46 of Set 9 | razole
# broken clouds
# Processed Record 47 of Set 9 | qostanay
# light rain
# Processed Record 48 of Set 9 | amapa
# broken clouds
# Processed Record 49 of Set 9 | waiblingen
# overcast clouds
# Processed Record 50 of Set 9 | sosnovo-ozerskoye
# few clouds
# Processed Record 1 of Set 10 | inhambane
# scattered clouds
# Processed Record 2 of Set 10 | araouane
# moderate rain
# Processed Record 4 of Set 10 | makokou
# few clouds
# Processed Record 5 of Set 10 | bodden town
# clear sky
# Processed Record 6 of Set 10 | villanueva de cordoba
# overcast clouds
# Processed Record 7 of Set 10 | evensk
# overcast clouds
# Processed Record 8 of Set 10 | tomatlan
# broken clouds
# Processed Record 9 of Set 10 | natchitoches
# overcast clouds
# Processed Record 10 of Set 10 | subottsi
# broken clouds
# Processed Record 11 of Set 10 | andros town
# scattered clouds
# Processed Record 12 of Set 10 | srednekolymsk
# broken clouds
# Processed Record 14 of Set 10 | derzhavinsk
# clear sky
# Processed Record 15 of Set 10 | hovd
# overcast clouds
# Processed Record 16 of Set 10 | arlit
# overcast clouds
# Processed Record 17 of Set 10 | bontang
# scattered clouds
# Processed Record 18 of Set 10 | ola
# clear sky
# Processed Record 20 of Set 10 | comodoro rivadavia
# overcast clouds
# Processed Record 21 of Set 10 | katsuura
# clear sky
# Processed Record 22 of Set 10 | awjilah
# overcast clouds
# Processed Record 23 of Set 10 | kavaratti
# clear sky
# Processed Record 24 of Set 10 | matamoros
# overcast clouds
# Processed Record 25 of Set 10 | shelkovskaya
# moderate rain
# Processed Record 26 of Set 10 | pyapon
# overcast clouds
# Processed Record 28 of Set 10 | constitucion
# clear sky
# Processed Record 29 of Set 10 | richards bay
# overcast clouds
# Processed Record 30 of Set 10 | luba
# broken clouds
# Processed Record 31 of Set 10 | san quintin
# clear sky
# Processed Record 32 of Set 10 | peniche
# overcast clouds
# Processed Record 33 of Set 10 | goderich
# overcast clouds
# Processed Record 35 of Set 10 | lavrentiya
# overcast clouds
# Processed Record 37 of Set 10 | ariquemes
# clear sky
# Processed Record 38 of Set 10 | quzhou
# overcast clouds
# Processed Record 39 of Set 10 | ouegoa
# overcast clouds
# Processed Record 41 of Set 10 | isabela
# overcast clouds
# Processed Record 42 of Set 10 | grimshaw
# few clouds
# Processed Record 43 of Set 10 | marratxi
# overcast clouds
# Processed Record 44 of Set 10 | saint-felix-de-valois
# light rain
# Processed Record 45 of Set 10 | bulgan
# overcast clouds
# Processed Record 46 of Set 10 | healesville
# few clouds
# Processed Record 47 of Set 10 | broome
# moderate rain
# Processed Record 48 of Set 10 | masingbi
# few clouds
# Processed Record 49 of Set 10 | barcelona
# scattered clouds
# Processed Record 50 of Set 10 | homer
# few clouds
# Processed Record 1 of Set 11 | volkhov
# scattered clouds
# Processed Record 2 of Set 11 | cabedelo
# broken clouds
# Processed Record 3 of Set 11 | alekseyevsk
# clear sky
# Processed Record 4 of Set 11 | rawah
# broken clouds
# Processed Record 5 of Set 11 | pisco
# scattered clouds
# Processed Record 8 of Set 11 | camopi
# clear sky
# Processed Record 9 of Set 11 | gladstone
# overcast clouds
# Processed Record 10 of Set 11 | ambovombe
# light rain
# Processed Record 11 of Set 11 | namatanai
# clear sky
# Processed Record 12 of Set 11 | ajdabiya
# broken clouds
# Processed Record 13 of Set 11 | mitsamiouli
# clear sky
# Processed Record 14 of Set 11 | port shepstone
# clear sky
# Processed Record 15 of Set 11 | kennewick
# overcast clouds
# Processed Record 16 of Set 11 | la ronge
# overcast clouds
# Processed Record 17 of Set 11 | suntar
# broken clouds
# Processed Record 19 of Set 11 | kolyshley
# overcast clouds
# Processed Record 20 of Set 11 | coahuayana
# light rain
# Processed Record 21 of Set 11 | juneau
# broken clouds
# Processed Record 22 of Set 11 | kapoeta
# overcast clouds
# Processed Record 23 of Set 11 | abakaliki
# scattered clouds
# Processed Record 24 of Set 11 | palmer
# overcast clouds
# Processed Record 26 of Set 11 | sistranda
# light rain
# Processed Record 27 of Set 11 | severo-yeniseyskiy
# scattered clouds
# Processed Record 28 of Set 11 | sao joao da barra
# broken clouds
# Processed Record 29 of Set 11 | sayyan
# clear sky
# Processed Record 31 of Set 11 | khorixas
# few clouds
# Processed Record 32 of Set 11 | brasilia
# scattered clouds
# Processed Record 33 of Set 11 | timizart
# few clouds
# Processed Record 34 of Set 11 | selma
# clear sky
# Processed Record 35 of Set 11 | aromashevo
# overcast clouds
# Processed Record 37 of Set 11 | gejiu
# overcast clouds
# Processed Record 38 of Set 11 | arenapolis
# few clouds
# Processed Record 39 of Set 11 | sao jose da coroa grande
# overcast clouds
# Processed Record 40 of Set 11 | sorong
# scattered clouds
# Processed Record 41 of Set 11 | havre-saint-pierre
# broken clouds
# Processed Record 42 of Set 11 | ikongo
# clear sky
# Processed Record 43 of Set 11 | urumqi
# scattered clouds
# Processed Record 44 of Set 11 | sola
# scattered clouds
# Processed Record 45 of Set 11 | musafirkhana
# light rain
# Processed Record 47 of Set 11 | kabo
# overcast clouds
# Processed Record 48 of Set 11 | manokwari
# few clouds
# Processed Record 49 of Set 11 | maceio
# broken clouds
# Processed Record 50 of Set 11 | joshimath
# broken clouds
# Processed Record 1 of Set 12 | itanagar
# clear sky
# Processed Record 2 of Set 12 | sehwan
# overcast clouds
# Processed Record 3 of Set 12 | biak
# overcast clouds
# Processed Record 4 of Set 12 | chifeng
# clear sky
# Processed Record 6 of Set 12 | young
# overcast clouds
# Processed Record 7 of Set 12 | saint-georges
# clear sky
# Processed Record 8 of Set 12 | auki
# broken clouds
# Processed Record 9 of Set 12 | chuchkovo
# broken clouds
# Processed Record 10 of Set 12 | aklavik
# scattered clouds
# Processed Record 11 of Set 12 | ormara
# clear sky
# Processed Record 12 of Set 12 | puyang
# scattered clouds
# Processed Record 13 of Set 12 | orlik
# few clouds
# Processed Record 14 of Set 12 | new milford
# clear sky
# Processed Record 15 of Set 12 | mezen
# broken clouds
# Processed Record 16 of Set 12 | voi
# overcast clouds
# Processed Record 17 of Set 12 | mackay
# broken clouds
# Processed Record 18 of Set 12 | tazovskiy
# light rain
# Processed Record 19 of Set 12 | touros
# light rain
# Processed Record 20 of Set 12 | ambon
# overcast clouds
# Processed Record 21 of Set 12 | miri
# light rain
# Processed Record 22 of Set 12 | fort nelson
# clear sky
# Processed Record 23 of Set 12 | jalu
# scattered clouds
# Processed Record 24 of Set 12 | svetlaya
# overcast clouds
# Processed Record 25 of Set 12 | leshan
# few clouds
# Processed Record 26 of Set 12 | macau
# broken clouds
# Processed Record 27 of Set 12 | otaru
# broken clouds
# Processed Record 28 of Set 12 | tiznit
# scattered clouds
# Processed Record 29 of Set 12 | kazanka
# overcast clouds
# Processed Record 30 of Set 12 | owando
# overcast clouds
# Processed Record 31 of Set 12 | shibetsu
# overcast clouds
# Processed Record 32 of Set 12 | kawalu
# few clouds
# Processed Record 33 of Set 12 | los llanos de aridane
# clear sky
# Processed Record 34 of Set 12 | mehamn
# broken clouds
# Processed Record 35 of Set 12 | banjar
# broken clouds
# Processed Record 36 of Set 12 | arman
# overcast clouds
# Processed Record 37 of Set 12 | kargasok
# broken clouds
# Processed Record 40 of Set 12 | caltanissetta
# clear sky
# Processed Record 41 of Set 12 | mahibadhoo
# mist
# Processed Record 42 of Set 12 | havelock
# clear sky
# Processed Record 43 of Set 12 | leh
# light rain
# Processed Record 44 of Set 12 | saint-pierre
# broken clouds
# Processed Record 45 of Set 12 | bereznik
# overcast clouds
# Processed Record 46 of Set 12 | anadyr
# few clouds
# Processed Record 47 of Set 12 | prado
# scattered clouds
# Processed Record 49 of Set 12 | keokuk
# overcast clouds
# Processed Record 50 of Set 12 | bocanda
# broken clouds
# Processed Record 1 of Set 13 | mandalgovi
# few clouds
# Processed Record 2 of Set 13 | moranbah
# clear sky
# Processed Record 3 of Set 13 | taltal
# few clouds
# Processed Record 4 of Set 13 | victoria point
# broken clouds
# Processed Record 5 of Set 13 | baracoa
# clear sky
# Processed Record 6 of Set 13 | lappeenranta
# overcast clouds
# Processed Record 7 of Set 13 | teya
# scattered clouds
# Processed Record 8 of Set 13 | cranbrook
# overcast clouds
# Processed Record 9 of Set 13 | anyksciai
# overcast clouds
# Processed Record 10 of Set 13 | marawi
# clear sky
# Processed Record 11 of Set 13 | tukrah
# overcast clouds
# Processed Record 12 of Set 13 | rondonopolis
# clear sky
# Processed Record 13 of Set 13 | kirkuk
# broken clouds
# Processed Record 14 of Set 13 | corpus christi
# overcast clouds
# Processed Record 15 of Set 13 | cozumel
# scattered clouds
# Processed Record 16 of Set 13 | novikovo
# broken clouds
# Processed Record 17 of Set 13 | varkkallai
# overcast clouds
# Processed Record 18 of Set 13 | abrego
# overcast clouds
# Processed Record 19 of Set 13 | shingu
# clear sky
# Processed Record 20 of Set 13 | gat
# few clouds
# Processed Record 21 of Set 13 | kalaleh
# clear sky
# Processed Record 22 of Set 13 | jizan
# scattered clouds
# Processed Record 23 of Set 13 | corinto
# clear sky
# Processed Record 24 of Set 13 | karasjok
# clear sky
# Processed Record 25 of Set 13 | calama
# light rain
# Processed Record 26 of Set 13 | bichura
# clear sky
# Processed Record 27 of Set 13 | namibe
# overcast clouds
# Processed Record 28 of Set 13 | swan hill
# clear sky
# Processed Record 29 of Set 13 | abu dhabi
# overcast clouds
# Processed Record 30 of Set 13 | zhigalovo
# scattered clouds
# Processed Record 32 of Set 13 | ulladulla
# overcast clouds
# Processed Record 33 of Set 13 | kamiiso
# scattered clouds
# Processed Record 34 of Set 13 | chapais
# clear sky
# Processed Record 35 of Set 13 | saint simons
# moderate rain
# Processed Record 36 of Set 13 | kaeo
# clear sky
# Processed Record 37 of Set 13 | khorramabad
# moderate rain
# Processed Record 38 of Set 13 | malumfashi
# clear sky
# Processed Record 39 of Set 13 | aden
# scattered clouds
# Processed Record 40 of Set 13 | itarema
# clear sky
# Processed Record 41 of Set 13 | aswan
# scattered clouds
# Processed Record 42 of Set 13 | kenai
# light rain
# Processed Record 43 of Set 13 | hadejia
# overcast clouds
# Processed Record 44 of Set 13 | fukue
# overcast clouds
# Processed Record 45 of Set 13 | matara
# clear sky
# Processed Record 46 of Set 13 | liverpool
# overcast clouds
# Processed Record 47 of Set 13 | port hedland
# clear sky
# Processed Record 48 of Set 13 | rehoboth
# overcast clouds
# Processed Record 49 of Set 13 | hamilton
# light rain
# Processed Record 50 of Set 13 | robertsport
# clear sky
# Processed Record 2 of Set 14 | bardiyah
# broken clouds
# Processed Record 4 of Set 14 | lira
# scattered clouds
# Processed Record 5 of Set 14 | manaus
# clear sky
# Processed Record 7 of Set 14 | mecca
# scattered clouds
# Processed Record 8 of Set 14 | sao benedito do rio preto
# light rain
# Processed Record 9 of Set 14 | pangkalanbuun
# clear sky
# Processed Record 10 of Set 14 | point pleasant
# overcast clouds
# Processed Record 11 of Set 14 | plouzane
# broken clouds
# Processed Record 12 of Set 14 | moose factory
# few clouds
# Processed Record 13 of Set 14 | saint anthony
# clear sky
# Processed Record 14 of Set 14 | lata
# clear sky
# Processed Record 15 of Set 14 | brewster
# light rain
# Processed Record 16 of Set 14 | verkhnevilyuysk
# light snow
# Processed Record 17 of Set 14 | dudinka
# overcast clouds
# Processed Record 18 of Set 14 | mbandaka
# broken clouds
# Processed Record 19 of Set 14 | ouargaye
# moderate rain
# Processed Record 20 of Set 14 | lewisburg
# overcast clouds
# Processed Record 21 of Set 14 | banda aceh
# overcast clouds
# Processed Record 22 of Set 14 | laja
# overcast clouds
# Processed Record 23 of Set 14 | narsaq
# broken clouds
# Processed Record 24 of Set 14 | barda
# overcast clouds
# Processed Record 25 of Set 14 | shakhtinsk
# broken clouds
# Processed Record 26 of Set 14 | ampanihy
# broken clouds
# Processed Record 27 of Set 14 | namanga
# clear sky
# Processed Record 28 of Set 14 | bayir
# clear sky
# Processed Record 29 of Set 14 | okoneshnikovo
# overcast clouds
# Processed Record 30 of Set 14 | codrington
# broken clouds
# Processed Record 31 of Set 14 | tessalit
# broken clouds
# Processed Record 32 of Set 14 | ambilobe
# few clouds
# Processed Record 34 of Set 14 | caravelas
# scattered clouds
# Processed Record 35 of Set 14 | hobyo
# few clouds
# Processed Record 36 of Set 14 | shirak
# clear sky
# Processed Record 37 of Set 14 | honningsvag
# overcast clouds
# Processed Record 38 of Set 14 | meadow lake
# overcast clouds
# Processed Record 39 of Set 14 | boende
# broken clouds
# Processed Record 40 of Set 14 | oum hadjer
# clear sky
# Processed Record 42 of Set 14 | emerald
# broken clouds
# Processed Record 43 of Set 14 | lisakovsk
# overcast clouds
# Processed Record 44 of Set 14 | yenagoa
# overcast clouds
# Processed Record 46 of Set 14 | jequie
# broken clouds
# Processed Record 47 of Set 14 | soyo
# moderate rain
# Processed Record 48 of Set 14 | harindanga
# scattered clouds
# Processed Record 49 of Set 14 | sevlievo
# overcast clouds
# Processed Record 50 of Set 14 | sheregesh
# clear sky
# Processed Record 1 of Set 15 | pampierstad
# light rain
# Processed Record 2 of Set 15 | udachnyy
# clear sky
# Processed Record 3 of Set 15 | matay
# overcast clouds
# Processed Record 4 of Set 15 | vieques
# overcast clouds
# Processed Record 5 of Set 15 | elmshorn
# few clouds
# Processed Record 6 of Set 15 | tamandare
# overcast clouds
# Processed Record 8 of Set 15 | thunder bay
# broken clouds
# Processed Record 9 of Set 15 | boa vista
# scattered clouds
# Processed Record 10 of Set 15 | salinas
# clear sky
# Processed Record 11 of Set 15 | sakakah
# overcast clouds
# Processed Record 12 of Set 15 | kloulklubed
# light rain
# Processed Record 14 of Set 15 | nichinan
# scattered clouds
# Processed Record 15 of Set 15 | tingi
# light rain
# Processed Record 17 of Set 15 | bogorodskoye
# clear sky
# Processed Record 18 of Set 15 | aranda de duero
# scattered clouds
# Processed Record 19 of Set 15 | verkhoyansk
# scattered clouds
# Processed Record 20 of Set 15 | makarov
# overcast clouds
# Processed Record 21 of Set 15 | mount darwin
# scattered clouds
# Processed Record 22 of Set 15 | vytegra
# broken clouds
# Processed Record 23 of Set 15 | huarmey
# clear sky
# Processed Record 24 of Set 15 | rosetta
# scattered clouds
# Processed Record 25 of Set 15 | cururupu
# few clouds
# Processed Record 26 of Set 15 | caborca
# overcast clouds
# Processed Record 27 of Set 15 | hinton
# few clouds
# Processed Record 28 of Set 15 | deputatskiy
# clear sky
# Processed Record 29 of Set 15 | glendive
# few clouds
# Processed Record 30 of Set 15 | baykit
# light rain
# Processed Record 31 of Set 15 | sao felix do xingu
# overcast clouds
# Processed Record 32 of Set 15 | nanortalik
# broken clouds
# Processed Record 33 of Set 15 | ilebo
# broken clouds
# Processed Record 34 of Set 15 | howard springs
# broken clouds
# Processed Record 35 of Set 15 | jaguey grande
# scattered clouds
# Processed Record 37 of Set 15 | shimanovsk
# scattered clouds
# Processed Record 38 of Set 15 | sena madureira
# clear sky
# Processed Record 40 of Set 15 | havoysund
# broken clouds
# Processed Record 41 of Set 15 | port keats
# few clouds
# Processed Record 42 of Set 15 | kedougou
# clear sky
# Processed Record 43 of Set 15 | dauriya
# broken clouds
# Processed Record 46 of Set 15 | eston
# clear sky
# Processed Record 48 of Set 15 | shatrovo
# broken clouds
# Processed Record 49 of Set 15 | fort smith
# overcast clouds
# Processed Record 50 of Set 15 | moelv
# clear sky
# Processed Record 1 of Set 16 | krasnokamensk
# clear sky
# Processed Record 2 of Set 16 | nador
# overcast clouds
# Processed Record 3 of Set 16 | mujiayingzi
# broken clouds
# Processed Record 4 of Set 16 | saint andrews
# overcast clouds
# Processed Record 5 of Set 16 | gigmoto
# overcast clouds
# Processed Record 6 of Set 16 | nsanje
# broken clouds
# Processed Record 7 of Set 16 | isiro
# broken clouds
# Processed Record 8 of Set 16 | tondon
# clear sky
# Processed Record 9 of Set 16 | inverell
# scattered clouds
# Processed Record 10 of Set 16 | pitimbu
# scattered clouds
# Processed Record 11 of Set 16 | ayorou
# overcast clouds
# Processed Record 12 of Set 16 | keita
# clear sky
# Processed Record 14 of Set 16 | ukiah
# overcast clouds
# Processed Record 15 of Set 16 | wloszczowa
# clear sky
# Processed Record 16 of Set 16 | mochudi
# clear sky
# Processed Record 17 of Set 16 | panjab
# overcast clouds
# Processed Record 18 of Set 16 | amot
# overcast clouds
# Processed Record 19 of Set 16 | merauke
# light intensity drizzle
# Processed Record 20 of Set 16 | graham
# few clouds
# Processed Record 21 of Set 16 | aguimes
# overcast clouds
# Processed Record 22 of Set 16 | bonnyville
# overcast clouds
# Processed Record 23 of Set 16 | mogadishu
# light rain
# Processed Record 24 of Set 16 | opunake
# overcast clouds
# Processed Record 25 of Set 16 | ejido
# light rain
# Processed Record 26 of Set 16 | kismayo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(100)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mahebourg      MU -20.4081   57.7000     23.16        88          40
# 1        Ushuaia      AR -54.8000  -68.3000      2.81        81          75
# 2   Punta Arenas      CL -53.1500  -70.9167      4.06        81           0
# 3    Provideniya      RU  64.3833 -173.3000      3.68        63          16
# 4        Fortuna      US  40.5982 -124.1573     18.57        66          75
# ..           ...     ...      ...       ...       ...       ...         ...
# 95        Beloha      MG -25.1667   45.0500     17.17        71          73
# 96  Ponta Do Sol      PT  32.6667  -17.1000     22.06        73           0
# 97       Morbach      DE  49.8167    7.1167     16.82        81          75
# 98   East London      ZA -33.0153   27.9116     15.52        58           0
# 99        Khilok      RU  51.3674  110.4676      6.99        96         100
#
#     Wind Speed Current Description
# 0         4.12    scattered clouds
# 1         0.00       broken clouds
# 2         4.45           clear sky
# 3         1.80          few clouds
# 4         2.24       broken clouds
# ..         ...                 ...
# 95        6.45       broken clouds
# 96        0.86           clear sky
# 97        2.77       broken clouds
# 98        2.57           clear sky
# 99        1.72     overcast clouds
#
# [100 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/3cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
